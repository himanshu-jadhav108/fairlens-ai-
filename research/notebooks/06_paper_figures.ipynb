# %% [markdown]
# # Notebook 06: Candidate Paper Figures Generation
#
# **Purpose:** Generate and preview candidate research figures (Pareto trade-offs, fairness deltas, performance deltas, attribution stability).
#
# **Methodological Note:** These are CANDIDATE figures for pilot evaluation. Radar charts are excluded in accordance with Methodological Correction 7.
#
# **Input Files:**
# - `research/results/processed/individual_runs.csv`
# - `research/results/figures/`

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from analysis.visualization import generate_candidate_figures

generate_candidate_figures(
    processed_dir='../results/processed',
    figures_dir='../results/figures'
)
print('Candidate figures generated.')
