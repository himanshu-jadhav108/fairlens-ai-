# %% [markdown]
# # Notebook 03: Mitigation Comparative Analysis (Pre vs In vs Post)
#
# **Purpose:** Compare fairness gains and accuracy trade-offs across Pre-processing (CorrelationRemover), In-processing (ExponentiatedGradient), and Post-processing (ThresholdOptimizer).
#
# **Input Files:**
# - `research/results/processed/individual_runs.csv`
# - `research/results/processed/summary_table.csv`

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
import pandas as pd

summary_path = '../results/processed/summary_table.csv'
if os.path.exists(summary_path):
    df_summary = pd.read_csv(summary_path)
    print(df_summary[['dataset', 'model', 'mitigation', 'delta_accuracy_mean', 'delta_dpd_mean']])
else:
    print('Summary table not found. Run aggregate_results.py first.')
